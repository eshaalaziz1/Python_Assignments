# %% [markdown]
# # UFO Sightings Data Analysis
#
# This Jupyter notebook outlines steps to load and analyze a dataset containing UFO sightings.
#
# ## Problem 1: Load and Read Data
#
# - **Task**: Import the `csv` module, load and read the UFO sightings dataset from `ufo-sightings.csv` using a `DictReader` in a `with` statement.
# - **Output**:
#   - Print the field names of the dataset.
#   - Iterate over the reader to store the data into a list named `ufosightings`.

# %%
import csv

file_path = "ufo-sightings.csv"
ufosightings = []

try:
    with open(file_path, mode="r", encoding="utf-8") as file:
        reader = csv.DictReader(file)
        print("Field names:", reader.fieldnames)

        for row in reader:
            ufosightings.append(row)

except FileNotFoundError:
    print(f"File not found at {file_path}")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")

if ufosightings:
    print(f"Loaded {len(ufosightings)} UFO sightings.")
# Out:
# Field names: ['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)', 'duration (hours/min)', 'comments', 'date posted', 'latitude', 'longitude ']
# Loaded 80332 UFO sightings.

# %% [markdown]
# ## Problem 2: Total Sightings
#
# - **Task**: Calculate the total number of UFO sightings.
# - **Output**: Print the total number of sightings stored in a variable `ufosightings_count`.

# %%
# Write your code here
ufosightings_count = len(ufosightings)

print(f"Total UFO Sightings: {ufosightings_count}")
# Out:
# Total UFO Sightings: 80332

# %% [markdown]
# ## Problem 3: Sightings in the US
#
# - **Task**: Determine how many UFO sightings occurred in the US.
# - **Output**: Store US sightings in a list named `sightings_us` and print the count.

# %%
# Write your code here
sightings_us = [sighting for sighting in ufosightings if sighting.get("country") == "us"]

print("Total UFO Sightings in the US:", len(sightings_us))
# Out:
# Total UFO Sightings in the US: 65114

# %% [markdown]
# ## Problem 4: Fireball Sightings Over Ten Seconds
#
# - **Task**: Find "fireball" sightings that lasted more than ten seconds in the US.
# - **Details**:
#   - Cast the duration to a float.
#   - Filter sightings where `shape` is "fireball" and duration is greater than 10 seconds.
# - **Output**: Print the datetime and state of each sighting.

# %%
# Write your code here

fireball_sightings = [
    (sighting["datetime"], sighting["state"])
    for sighting in sightings_us
    if sighting.get("shape") == "fireball" and float(sighting.get("duration (seconds)", 0)) > 10
]

for datetime, state in fireball_sightings:
    print(f"Date & Time: {datetime}, State: {state}")

print("Total Fireball Sightings Over 10 Seconds in the US:", len(fireball_sightings))
# Out:
# Date & Time: 1968-10-10 19:00:00, State: nc
# Date & Time: 1998-10-10 03:30:00, State: az
# Date & Time: 1998-10-10 23:50:00, State: tn
# Date & Time: 1999-10-10 11:00:00, State: ca
# Date & Time: 2011-10-10 20:00:00, State: ct
# Date & Time: 2011-10-10 21:00:00, State: oh
# Date & Time: 2012-10-10 20:30:00, State: nm
# Date & Time: 1987-10-11 23:59:00, State: mo
# Date & Time: 2004-10-11 22:29:00, State: tx
# Date & Time: 2006-10-11 19:00:00, State: ca
# Date & Time: 2008-10-11 22:20:00, State: nm
# Date & Time: 2012-10-11 19:30:00, State: pa
# Date & Time: 2012-10-11 20:30:00, State: nm
# Date & Time: 2013-10-11 16:35:00, State: mi
# Date & Time: 2013-10-11 20:00:00, State: oh
# Date & Time: 2013-10-11 20:15:00, State: oh
# Date & Time: 2013-10-11 20:15:00, State: ky
# Date & Time: 2013-10-11 20:20:00, State: ma
# Date & Time: 1980-10-01 20:00:00, State: al
# Date & Time: 1982-10-01 22:10:00, State: mi
# Date & Time: 1987-10-01 21:00:00, State: nh
# Date & Time: 1996-10-01 22:30:00, State: tx
# Date & Time: 1998-10-01 04:30:00, State: nm
# Date & Time: 1999-10-01 00:30:00, State: tx
# Date & Time: 2006-10-01 19:45:00, State: nv
# Date & Time: 2006-10-01 22:00:00, State: nm
# Date & Time: 2006-10-01 22:18:00, State: az
# Date & Time: 2006-10-01 23:15:00, State: co
# Date & Time: 2006-10-01 23:20:00, State: co
# Date & Time: 2011-10-01 21:43:00, State: mo
# Date & Time: 2011-10-01 21:43:00, State: mo
# Date & Time: 2012-10-01 19:30:00, State: il
# Date & Time: 2012-10-01 20:00:00, State: ca
# Date & Time: 2012-10-01 23:00:00, State: in
# Date & Time: 2013-10-01 21:30:00, State: ga
# Date & Time: 2013-10-01 22:45:00, State: ny
# Date & Time: 1998-10-12 19:00:00, State: nc
# Date & Time: 1999-10-12 05:11:00, State: or
# Date & Time: 1999-10-12 12:07:00, State: pa
# Date & Time: 1999-10-12 22:00:00, State: az
# Date & Time: 2000-10-12 19:30:00, State: ok
# Date & Time: 2003-10-12 13:08:00, State: pa
# Date & Time: 2004-10-12 21:10:00, State: wa
# Date & Time: 2005-10-12 00:00:00, State: ca
# Date & Time: 2012-10-12 00:00:00, State: fl
# Date & Time: 2012-10-12 20:30:00, State: fl
# Date & Time: 2013-10-12 07:45:00, State: mo
# Date & Time: 2013-10-12 21:00:00, State: oh
# Date & Time: 2013-10-12 21:15:00, State: oh
# Date & Time: 2013-10-12 23:28:00, State: ca
# Date & Time: NaT, State: oh
# Date & Time: 2000-10-13 06:45:00, State: ok
# Date & Time: 2000-10-13 08:00:00, State: ks
# Date & Time: 2000-10-13 19:20:00, State: ok
# Date & Time: 2000-10-13 19:30:00, State: tx
# Date & Time: 2000-10-13 19:53:00, State: ok
# Date & Time: 2011-10-13 20:30:00, State: nc
# Date & Time: 2012-10-13 21:00:00, State: ct
# Date & Time: 2012-10-13 21:45:00, State: nj
# Date & Time: 2013-10-13 19:00:00, State: ny
# Date & Time: 2013-10-13 19:40:00, State: pa
# Date & Time: 2002-10-14 19:00:00, State: ca
# Date & Time: 2002-10-14 19:02:00, State: or
# Date & Time: 2002-10-14 19:02:00, State: ca
# Date & Time: 2002-10-14 19:03:00, State: ca
# Date & Time: 2002-10-14 19:10:00, State: ca
# Date & Time: 2006-10-14 20:15:00, State: ca
# Date & Time: 2009-10-14 22:00:00, State: or
# Date & Time: 2012-10-14 20:00:00, State: pa
# Date & Time: 1957-10-15 22:00:00, State: co
# Date & Time: 1967-10-15 21:00:00, State: ca
# Date & Time: 1980-10-15 02:30:00, State: oh
# Date & Time: 1990-10-15 03:00:00, State: me
# Date & Time: 1999-10-15 02:00:00, State: ma
# Date & Time: 2001-10-15 20:23:00, State: wa
# Date & Time: 2002-10-15 04:30:00, State: mi
# Date & Time: 2003-10-15 22:00:00, State: ny
# Date & Time: 2006-10-15 00:15:00, State: ut
# Date & Time: 2007-10-15 20:00:00, State: mt
# Date & Time: 2010-10-15 21:27:00, State: ny
# Date & Time: 2011-10-15 23:00:00, State: mo
# Date & Time: 1997-10-16 05:34:00, State: nc
# Date & Time: 2000-10-16 12:22:00, State: ct
# Date & Time: 2004-10-16 23:00:00, State: az
# Date & Time: 2008-10-16 23:00:00, State: sc
# Date & Time: 2012-10-16 21:00:00, State: vt
# Date & Time: 1998-10-17 16:00:00, State: fl
# Date & Time: 2001-10-17 00:00:00, State: oh
# Date & Time: 2006-10-17 22:10:00, State: fl
# Date & Time: 2000-10-18 20:43:00, State: fl
# Date & Time: 2003-10-18 21:30:00, State: wi
# Date & Time: 2003-10-18 21:30:00, State: wi
# Date & Time: 2003-10-18 21:40:00, State: mo
# Date & Time: 2011-10-18 23:15:00, State: ca
# Date & Time: 2013-10-18 00:00:00, State: or
# Date & Time: 2013-10-18 08:00:00, State: fl
# Date & Time: 2013-10-18 20:15:00, State: in
# Date & Time: 2013-10-18 21:30:00, State: nh
# Date & Time: 2013-10-18 21:30:00, State: fl
# Date & Time: 2013-10-18 21:45:00, State: oh
# Date & Time: 2013-10-18 22:34:00, State: oh
# Date & Time: 2013-10-18 22:34:00, State: oh
# Date & Time: 1998-10-19 18:00:00, State: va
# Date & Time: 2001-10-19 19:50:00, State: ky
# Date & Time: 2007-10-19 19:20:00, State: tx
# Date & Time: 2007-10-19 19:30:00, State: tx
# Date & Time: 2007-10-19 20:00:00, State: tx
# Date & Time: 2011-10-19 06:40:00, State: ma
# Date & Time: 2012-10-19 19:15:00, State: ca
# Date & Time: 2012-10-19 20:30:00, State: tn
# Date & Time: 2012-10-19 22:00:00, State: tn
# Date & Time: 2013-10-19 20:15:00, State: az
# Date & Time: 2013-10-19 20:30:00, State: az
# Date & Time: 1973-10-20 23:30:00, State: in
# Date & Time: 1974-10-20 07:00:00, State: ca
# Date & Time: 1995-10-20 22:00:00, State: or
# Date & Time: 2003-10-20 20:45:00, State: nc
# Date & Time: 2003-10-20 20:45:00, State: ga
# Date & Time: 2003-10-20 20:45:00, State: nc
# Date & Time: 2003-10-20 20:50:00, State: nc
# Date & Time: 2005-10-20 04:15:00, State: wv
# Date & Time: 2010-10-20 19:00:00, State: id
# Date & Time: 2012-10-20 06:00:00, State: or
# Date & Time: 2012-10-20 18:40:00, State: nh
# Date & Time: 2012-10-20 19:20:00, State: tx
# Date & Time: 2012-10-20 19:30:00, State: nc
# Date & Time: 2012-10-20 19:45:00, State: wi
# Date & Time: 2012-10-20 20:30:00, State: wi
# Date & Time: 2001-10-21 08:30:00, State: nc
# Date & Time: 2003-10-21 19:00:00, State: ca
# Date & Time: 2013-10-21 06:15:00, State: tx
# Date & Time: 2013-10-21 19:20:00, State: mo
# Date & Time: 2013-10-21 19:50:00, State: ma
# Date & Time: 2013-10-21 21:00:00, State: nj
# Date & Time: NaT, State: wa
# Date & Time: 1998-10-02 09:20:00, State: az
# Date & Time: 2010-10-02 20:45:00, State: ca
# Date & Time: 2012-10-02 22:51:00, State: ky
# Date & Time: 2013-10-02 20:00:00, State: oh
# Date & Time: 2013-10-02 21:00:00, State: oh
# Date & Time: NaT, State: nc
# Date & Time: 2002-10-22 21:00:00, State: fl
# Date & Time: 2003-10-22 21:00:00, State: va
# Date & Time: 2010-10-22 05:45:00, State: az
# Date & Time: 2011-10-22 14:15:00, State: ca
# Date & Time: 2011-10-22 21:57:00, State: pa
# Date & Time: 2012-10-22 07:00:00, State: ca
# Date & Time: 2012-10-22 18:20:00, State: ny
# Date & Time: 1998-10-23 21:45:00, State: la
# Date & Time: 2005-10-23 02:00:00, State: ks
# Date & Time: 2005-10-23 12:00:00, State: nm
# Date & Time: 2010-10-23 19:40:00, State: az
# Date & Time: 2012-10-23 19:45:00, State: sc
# Date & Time: 2013-10-23 18:30:00, State: nh
# Date & Time: 2008-10-24 19:00:00, State: ca
# Date & Time: 2008-10-24 20:10:00, State: ca
# Date & Time: 2008-10-24 23:00:00, State: va
# Date & Time: 2011-10-24 07:38:00, State: pa
# Date & Time: 2011-10-24 20:00:00, State: sc
# Date & Time: 2012-10-24 00:30:00, State: il
# Date & Time: 2012-10-24 19:40:00, State: pa
# Date & Time: 2012-10-24 20:00:00, State: sc
# Date & Time: 2013-10-24 04:45:00, State: ca
# Date & Time: 2013-10-24 21:38:00, State: pa
# Date & Time: 2000-10-25 20:15:00, State: az
# Date & Time: 2006-10-25 00:00:00, State: fl
# Date & Time: 2006-10-25 20:54:00, State: fl
# Date & Time: 2006-10-25 21:00:00, State: fl
# Date & Time: 2008-10-25 21:30:00, State: in
# Date & Time: 2013-10-25 20:15:00, State: tx
# Date & Time: 2013-10-25 21:40:00, State: oh
# Date & Time: 1998-10-26 04:50:00, State: wi
# Date & Time: 1998-10-26 21:50:00, State: ca
# Date & Time: NaT, State: wa
# Date & Time: 2004-10-26 20:00:00, State: nv
# Date & Time: 2007-10-26 21:00:00, State: tx
# Date & Time: 2008-10-26 21:00:00, State: va
# Date & Time: 2010-10-26 18:30:00, State: la
# Date & Time: 2013-10-26 18:00:00, State: az
# Date & Time: 2013-10-26 19:00:00, State: sc
# Date & Time: 2013-10-26 21:36:00, State: fl
# Date & Time: 2013-10-26 21:45:00, State: fl
# Date & Time: 2013-10-26 23:00:00, State: ok
# Date & Time: 2000-10-27 08:30:00, State: az
# Date & Time: 2004-10-27 19:35:00, State: ca
# Date & Time: 2010-10-27 21:00:00, State: fl
# Date & Time: 2012-10-27 11:30:00, State: pa
# Date & Time: 2012-10-27 20:15:00, State: co
# Date & Time: 2012-10-27 20:40:00, State: ny
# Date & Time: 2012-10-27 21:35:00, State: ny
# Date & Time: 2013-10-27 21:50:00, State: fl
# Date & Time: 2013-01-10 22:00:00, State: oh
# Date & Time: 2014-01-10 20:30:00, State: nh
# Date & Time: 2014-01-10 20:50:00, State: ca
# Date & Time: 2014-01-10 22:58:00, State: hi
# Date & Time: 2001-11-10 21:51:00, State: fl
# Date & Time: 2007-11-10 20:00:00, State: fl
# Date & Time: 2008-11-10 19:00:00, State: tn
# Date & Time: 2012-11-10 18:20:00, State: ut
# Date & Time: 2012-11-10 19:00:00, State: nj
# Date & Time: 2012-11-10 21:00:00, State: tx
# Date & Time: 2013-11-10 16:30:00, State: ca
# Date & Time: 2013-11-10 18:25:00, State: wa
# Date & Time: 2013-11-10 19:30:00, State: ak
# Date & Time: 2013-11-10 19:30:00, State: fl
# Date & Time: 2013-11-10 21:00:00, State: tx
# Date & Time: 2013-11-10 21:00:00, State: tx
# Date & Time: 1998-11-11 19:45:00, State: oh
# Date & Time: 2012-11-11 07:00:00, State: ga
# Date & Time: 2012-11-11 17:56:00, State: ca
# Date & Time: 2013-11-11 18:23:00, State: id
# Date & Time: 1997-11-01 18:50:00, State: mo
# Date & Time: 1998-11-01 00:00:00, State: mi
# Date & Time: 1998-01-11 00:10:00, State: co
# Date & Time: 1998-11-01 01:30:00, State: mi
# Date & Time: 2001-01-11 20:45:00, State: co
# Date & Time: 2001-01-11 21:30:00, State: il
# Date & Time: 2002-11-01 20:30:00, State: az
# Date & Time: 2005-11-01 17:05:00, State: ca
# Date & Time: 2005-11-01 19:35:00, State: mo
# Date & Time: 2009-01-11 00:02:00, State: ca
# Date & Time: 2010-01-11 01:40:00, State: fl
# Date & Time: 2011-11-01 19:30:00, State: me
# Date & Time: 2011-11-01 21:00:00, State: nc
# Date & Time: 2012-01-11 19:45:00, State: mo
# Date & Time: 2012-01-11 22:00:00, State: ny
# Date & Time: 2012-01-11 22:00:00, State: ny
# Date & Time: 2012-11-01 23:30:00, State: ga
# Date & Time: 2013-11-01 00:28:00, State: fl
# Date & Time: 2013-11-01 19:00:00, State: oh
# Date & Time: 2013-11-01 19:15:00, State: oh
# Date & Time: 2013-11-01 19:30:00, State: oh
# Date & Time: 2013-11-01 20:15:00, State: fl
# Date & Time: 2013-11-01 21:00:00, State: ny
# Date & Time: 2014-01-11 19:00:00, State: ca
# Date & Time: 2014-01-11 22:40:00, State: fl
# Date & Time: 1998-11-12 18:30:00, State: or
# Date & Time: 2006-11-12 01:00:00, State: ca
# Date & Time: 2008-11-12 09:15:00, State: ca
# Date & Time: 2011-11-12 22:15:00, State: pa
# Date & Time: 2012-11-12 17:00:00, State: pa
# Date & Time: 2012-11-12 22:30:00, State: oh
# Date & Time: 2000-11-13 22:00:00, State: ks
# Date & Time: 2003-11-13 13:34:00, State: ny
# Date & Time: 2005-11-13 20:00:00, State: oh
# Date & Time: 2008-11-13 18:00:00, State: il
# Date & Time: 2009-11-13 19:00:00, State: oh
# Date & Time: 2009-11-13 19:35:00, State: ky
# Date & Time: 2010-11-13 10:00:00, State: ca
# Date & Time: 2011-11-13 18:30:00, State: oh
# Date & Time: 1999-11-16 18:05:00, State: mo
# Date & Time: 1999-11-16 18:06:00, State: ky
# Date & Time: 1999-11-16 18:06:00, State: il
# Date & Time: 1999-11-16 18:20:00, State: tn
# Date & Time: 1999-11-16 18:30:00, State: pa
# Date & Time: 1999-11-16 18:30:00, State: il
# Date & Time: 1999-11-16 18:40:00, State: in
# Date & Time: 1999-11-16 19:00:00, State: in
# Date & Time: 1999-11-16 19:00:00, State: oh
# Date & Time: 1999-11-16 19:00:00, State: wi
# Date & Time: 1999-11-16 19:00:00, State: oh
# Date & Time: 1999-11-16 19:00:00, State: mi
# Date & Time: 1999-11-16 19:00:00, State: oh
# Date & Time: 1999-11-16 19:00:00, State: mi
# Date & Time: 1999-11-16 19:00:00, State: mi
# Date & Time: 1999-11-16 19:00:00, State: mi
# Date & Time: 1999-11-16 19:00:00, State: oh
# Date & Time: 1999-11-16 19:00:00, State: wi
# Date & Time: 1999-11-16 19:00:00, State: mi
# Date & Time: 1999-11-16 19:04:00, State: in
# Date & Time: 1999-11-16 19:04:00, State: oh
# Date & Time: 1999-11-16 19:04:00, State: oh
# Date & Time: 1999-11-16 19:05:00, State: mi
# Date & Time: 1999-11-16 19:05:00, State: oh
# Date & Time: 1999-11-16 19:05:00, State: oh
# Date & Time: 1999-11-16 19:05:00, State: in
# Date & Time: 1999-11-16 19:06:00, State: mi
# Date & Time: 1999-11-16 19:08:00, State: mi
# Date & Time: 1999-11-16 19:08:00, State: oh
# Date & Time: 1999-11-16 19:10:00, State: oh
# Date & Time: 1999-11-16 19:12:00, State: oh
# Date & Time: 1999-11-16 19:12:00, State: mi
# Date & Time: 1999-11-16 19:15:00, State: il
# Date & Time: 1999-11-16 19:15:00, State: oh
# Date & Time: 1999-11-16 21:05:00, State: il
# Date & Time: 1999-11-16 21:30:00, State: ky
# Date & Time: 2007-11-16 19:00:00, State: oh
# Date & Time: 2012-11-16 04:00:00, State: ks
# Date & Time: 2012-11-16 18:00:00, State: ct
# Date & Time: 2012-11-16 19:00:00, State: ca
# Date & Time: 2012-11-16 20:00:00, State: ca
# Date & Time: 2012-11-16 23:38:00, State: ny
# Date & Time: 2013-11-16 01:00:00, State: ca
# Date & Time: 2013-11-16 18:00:00, State: ct
# Date & Time: 2013-11-16 18:30:00, State: ri
# Date & Time: 2013-11-16 20:00:00, State: az
# Date & Time: 2013-11-16 23:00:00, State: ma
# Date & Time: 1990-11-17 04:30:00, State: me
# Date & Time: 1998-11-17 17:35:00, State: fl
# Date & Time: 2002-11-17 03:00:00, State: tn
# Date & Time: 2009-11-17 23:05:00, State: ca
# Date & Time: 2010-11-17 21:30:00, State: nc
# Date & Time: 2011-11-17 08:00:00, State: tx
# Date & Time: 2011-11-17 19:30:00, State: in
# Date & Time: 2012-11-17 18:10:00, State: nh
# Date & Time: 2012-11-17 18:12:00, State: ma
# Date & Time: 2012-11-17 18:30:00, State: va
# Date & Time: 2012-11-17 19:00:00, State: wi
# Date & Time: 2012-11-17 19:13:00, State: wi
# Date & Time: 2013-11-17 18:00:00, State: md
# Date & Time: 2013-11-17 18:30:00, State: co
# Date & Time: 2013-11-17 22:02:00, State: fl
# Date & Time: 2005-11-18 18:30:00, State: mt
# Date & Time: 2006-11-18 12:00:00, State: ca
# Date & Time: 2007-11-18 03:30:00, State: ny
# Date & Time: 2007-11-18 20:00:00, State: fl
# Date & Time: 2008-11-18 21:00:00, State: pa
# Date & Time: 2011-11-18 21:36:00, State: mi
# Date & Time: 2012-11-18 17:00:00, State: il
# Date & Time: 2012-11-18 19:15:00, State: ky
# Date & Time: 2012-11-18 19:20:00, State: ky
# Date & Time: 2012-11-18 21:05:00, State: ga
# Date & Time: 2012-11-18 22:00:00, State: mi
# Date & Time: 2013-11-18 17:59:00, State: md
# Date & Time: 2010-11-19 16:10:00, State: ak
# Date & Time: 2011-11-19 18:35:00, State: ga
# Date & Time: 2012-11-19 19:00:00, State: wv
# Date & Time: 2012-11-19 22:31:00, State: ny
# Date & Time: 2013-11-19 17:10:00, State: fl
# Date & Time: 2013-11-19 19:00:00, State: ca
# Date & Time: 2013-11-19 20:00:00, State: mo
# Date & Time: 2013-11-19 20:20:00, State: md
# Date & Time: 1965-01-01 20:00:00, State: ia
# Date & Time: 1995-01-01 02:00:00, State: ca
# Date & Time: 2003-01-01 00:01:00, State: ca
# Date & Time: 2003-01-01 06:00:00, State: ca
# Date & Time: 2007-01-01 00:06:00, State: ca
# Date & Time: 2007-01-01 00:20:00, State: fl
# Date & Time: 2008-01-01 00:08:00, State: ak
# Date & Time: 2008-01-01 08:30:00, State: fl
# Date & Time: 2009-01-01 01:10:00, State: fl
# Date & Time: 2009-01-01 19:00:00, State: ct
# Date & Time: 2010-01-01 00:00:00, State: mo
# Date & Time: 2010-01-01 00:24:00, State: fl
# Date & Time: 2011-01-01 00:00:00, State: md
# Date & Time: 2011-01-01 00:07:00, State: ut
# Date & Time: 2011-01-01 00:10:00, State: co
# Date & Time: 2011-01-01 00:13:00, State: il
# Date & Time: 2011-01-01 00:30:00, State: il
# Date & Time: 2011-01-01 22:27:00, State: pa
# Date & Time: NaT, State: tx
# Date & Time: 2012-01-01 00:05:00, State: fl
# Date & Time: 2012-01-01 00:05:00, State: ca
# Date & Time: 2012-01-01 00:25:00, State: ny
# Date & Time: 2012-01-01 00:30:00, State: ky
# Date & Time: 2012-01-01 00:38:00, State: ny
# Date & Time: 2012-01-01 00:45:00, State: fl
# Date & Time: 2012-01-01 19:50:00, State: oh
# Date & Time: 2013-01-01 00:02:00, State: ms
# Date & Time: 2013-01-01 00:05:00, State: ca
# Date & Time: 2013-01-01 00:10:00, State: ca
# Date & Time: 2013-01-01 00:15:00, State: sc
# Date & Time: 2013-01-01 00:15:00, State: fl
# Date & Time: 2013-01-01 00:37:00, State: fl
# Date & Time: 2013-01-01 00:55:00, State: fl
# Date & Time: 2013-01-01 01:35:00, State: ut
# Date & Time: 2013-01-01 08:00:00, State: fl
# Date & Time: 2013-01-01 18:45:00, State: hi
# Date & Time: 2013-01-01 20:01:00, State: ca
# Date & Time: 2013-01-01 20:35:00, State: fl
# Date & Time: 2013-01-01 21:25:00, State: hi
# Date & Time: 2014-01-01 00:12:00, State: ny
# Date & Time: 2014-01-01 00:15:00, State: fl
# Date & Time: 2014-01-01 00:20:00, State: va
# Date & Time: 2014-01-01 00:30:00, State: fl
# Date & Time: 2014-01-01 01:00:00, State: nj
# Date & Time: 2014-01-01 01:00:00, State: fl
# Date & Time: 2014-01-01 17:15:00, State: me
# Date & Time: 2014-01-01 18:30:00, State: il
# Date & Time: 2014-01-01 20:15:00, State: pa
# Date & Time: 2014-01-01 23:00:00, State: sc
# Date & Time: 1999-11-20 23:45:00, State: ca
# Date & Time: 2002-11-20 11:00:00, State: pa
# Date & Time: 2003-11-20 17:30:00, State: nm
# Date & Time: 2008-11-20 22:45:00, State: ga
# Date & Time: 2008-11-20 23:45:00, State: ar
# Date & Time: 2013-11-20 04:40:00, State: nm
# Date & Time: 2013-11-20 16:50:00, State: vt
# Date & Time: 2013-11-20 17:00:00, State: vt
# Date & Time: 2013-11-20 18:00:00, State: ma
# Date & Time: 2013-11-20 18:15:00, State: pa
# Date & Time: 2013-11-20 21:00:00, State: nh
# Date & Time: 2011-11-21 13:00:00, State: ca
# Date & Time: 2011-11-21 18:30:00, State: ca
# Date & Time: 2012-11-21 17:00:00, State: wi
# Date & Time: 2012-11-21 19:30:00, State: tx
# Date & Time: 2012-11-21 21:15:00, State: fl
# Date & Time: 2012-11-21 21:30:00, State: al
# Date & Time: 2013-11-21 06:25:00, State: ny
# Date & Time: 2013-11-21 19:57:00, State: nm
# Date & Time: 2013-11-21 21:00:00, State: wa
# Date & Time: 2013-11-21 22:00:00, State: fl
# Date & Time: 1998-11-02 03:45:00, State: mi
# Date & Time: 2000-11-02 22:00:00, State: tx
# Date & Time: 2003-01-12 01:30:00, State: ca
# Date & Time: 2003-01-12 10:16:00, State: ca
# Date & Time: 2003-01-12 20:12:00, State: ut
# Date & Time: 2004-01-12 07:49:00, State: ca
# Date & Time: 2005-11-02 18:25:00, State: wi
# Date & Time: 2005-11-02 23:45:00, State: nc
# Date & Time: 2006-01-12 07:00:00, State: mt
# Date & Time: 2007-11-02 19:20:00, State: ca
# Date & Time: 2008-01-12 01:30:00, State: ca
# Date & Time: 2008-11-02 02:15:00, State: md
# Date & Time: 2008-11-02 20:51:00, State: ct
# Date & Time: 2010-11-02 19:18:00, State: vt
# Date & Time: 2010-01-12 22:45:00, State: ca
# Date & Time: 2011-01-12 08:52:00, State: ca
# Date & Time: 2012-11-02 21:15:00, State: wi
# Date & Time: 2012-11-02 23:58:00, State: ca
# Date & Time: 2013-11-02 00:00:00, State: ar
# Date & Time: 2013-01-12 16:45:00, State: fl
# Date & Time: 2013-11-02 22:00:00, State: ar
# Date & Time: 2013-11-02 22:30:00, State: ri
# Date & Time: 2014-01-12 18:30:00, State: fl
# Date & Time: 1999-11-22 23:30:00, State: fl
# Date & Time: 2001-11-22 16:15:00, State: in
# Date & Time: NaT, State: sc
# Date & Time: 2005-11-22 01:45:00, State: ca
# Date & Time: 2005-11-22 19:15:00, State: ca
# Date & Time: 2009-11-22 21:44:00, State: ca
# Date & Time: 2012-11-22 16:30:00, State: mi
# Date & Time: 2012-11-22 18:10:00, State: oh
# Date & Time: 2012-11-22 18:36:00, State: ma
# Date & Time: 2012-11-22 19:30:00, State: nm
# Date & Time: 2012-11-22 20:15:00, State: fl
# Date & Time: 2012-11-22 20:30:00, State: nv
# Date & Time: 2012-11-22 21:00:00, State: fl
# Date & Time: 2002-11-23 22:18:00, State: il
# Date & Time: 2011-11-23 21:15:00, State: nh
# Date & Time: 2011-11-23 21:35:00, State: az
# Date & Time: 2012-11-23 18:00:00, State: wi
# Date & Time: 2012-11-23 19:00:00, State: ct
# Date & Time: 2012-11-23 19:20:00, State: sc
# Date & Time: 2013-11-23 19:00:00, State: sc
# Date & Time: 2013-11-23 20:55:00, State: az
# Date & Time: 1999-11-24 10:00:00, State: ca
# Date & Time: 2004-11-24 20:30:00, State: ca
# Date & Time: 2006-11-24 10:00:00, State: nc
# Date & Time: 2006-11-24 13:30:00, State: ma
# Date & Time: 2010-11-24 20:00:00, State: mn
# Date & Time: 2011-11-24 18:00:00, State: fl
# Date & Time: 2011-11-24 18:30:00, State: ny
# Date & Time: 2011-11-24 19:50:00, State: nj
# Date & Time: 2011-11-24 20:45:00, State: pa
# Date & Time: 2012-11-24 19:00:00, State: fl
# Date & Time: 2012-11-24 21:00:00, State: fl
# Date & Time: 2013-11-24 18:35:00, State: il
# Date & Time: 2006-11-25 18:15:00, State: tn
# Date & Time: 2011-11-25 21:00:00, State: ct
# Date & Time: 2011-11-25 21:30:00, State: mn
# Date & Time: 2011-11-25 21:55:00, State: ca
# Date & Time: 2013-11-25 19:00:00, State: pa
# Date & Time: 2013-11-25 21:45:00, State: nj
# Date & Time: 2002-11-26 06:10:00, State: or
# Date & Time: 2003-11-26 03:00:00, State: az
# Date & Time: 2007-11-26 20:50:00, State: ca
# Date & Time: 2009-11-26 19:40:00, State: az
# Date & Time: 2011-11-26 17:05:00, State: il
# Date & Time: 2013-11-26 19:05:00, State: az
# Date & Time: 1981-11-27 09:00:00, State: nj
# Date & Time: 1998-11-27 15:35:00, State: wv
# Date & Time: 2003-11-27 19:00:00, State: ca
# Date & Time: 2004-11-27 13:05:00, State: wa
# Date & Time: 2007-11-27 22:00:00, State: il
# Date & Time: 2008-11-27 20:00:00, State: ca
# Date & Time: 1997-11-28 19:30:00, State: wi
# Date & Time: 2000-11-28 21:00:00, State: wa
# Date & Time: 2002-11-28 06:15:00, State: wa
# Date & Time: 2002-11-28 20:30:00, State: co
# Date & Time: 2006-11-28 17:25:00, State: al
# Date & Time: 2006-11-28 17:30:00, State: al
# Date & Time: 2006-11-28 17:30:00, State: al
# Date & Time: 2006-11-28 18:40:00, State: nc
# Date & Time: 2006-11-28 19:00:00, State: ga
# Date & Time: 2012-11-28 17:35:00, State: tx
# Date & Time: 2012-11-28 22:00:00, State: ca
# Date & Time: 2013-11-28 18:52:00, State: ny
# Date & Time: 2013-11-28 20:00:00, State: il
# Date & Time: 2013-11-28 20:28:00, State: wi
# Date & Time: 2013-11-28 22:40:00, State: fl
# Date & Time: 1998-11-29 01:50:00, State: nc
# Date & Time: 1998-11-29 19:10:00, State: ca
# Date & Time: 2002-11-29 06:15:00, State: wa
# Date & Time: 2003-11-29 22:30:00, State: ia
# Date & Time: 2012-11-29 16:25:00, State: ri
# Date & Time: 2013-11-29 18:45:00, State: sc
# Date & Time: 2013-11-29 20:15:00, State: me
# Date & Time: 2004-11-30 23:45:00, State: mt
# Date & Time: 2006-11-30 12:17:00, State: az
# Date & Time: 2012-11-30 20:47:00, State: ma
# Date & Time: 2013-11-30 16:00:00, State: fl
# Date & Time: 2013-11-30 18:30:00, State: ca
# Date & Time: 2013-11-30 18:30:00, State: ca
# Date & Time: 2013-11-30 20:02:00, State: or
# Date & Time: 2013-11-30 21:10:00, State: ny
# Date & Time: 2013-11-30 21:30:00, State: ma
# Date & Time: 2013-11-30 22:30:00, State: wv
# Date & Time: 1997-01-13 17:30:00, State: il
# Date & Time: 1998-11-03 21:00:00, State: az
# Date & Time: 2000-01-13 22:30:00, State: ky
# Date & Time: 2005-11-03 16:40:00, State: ca
# Date & Time: 2005-11-03 19:49:00, State: wi
# Date & Time: 2006-11-03 17:15:00, State: va
# Date & Time: 2006-01-13 17:30:00, State: ok
# Date & Time: 2006-01-13 18:36:00, State: ok
# Date & Time: 2010-11-03 19:15:00, State: ca
# Date & Time: 2012-11-03 17:30:00, State: ca
# Date & Time: 2012-11-03 18:45:00, State: wa
# Date & Time: 2012-11-03 21:00:00, State: mi
# Date & Time: 2012-01-13 23:04:00, State: ca
# Date & Time: 2012-11-03 23:45:00, State: ia
# Date & Time: 2013-11-03 18:25:00, State: tx
# Date & Time: 2013-11-03 18:40:00, State: fl
# Date & Time: 2013-11-03 18:50:00, State: oh
# Date & Time: 2013-01-13 20:30:00, State: fl
# Date & Time: 1999-01-14 19:00:00, State: fl
# Date & Time: 2004-11-04 19:15:00, State: or
# Date & Time: 2007-11-04 21:55:00, State: ca
# Date & Time: 2008-01-14 19:00:00, State: az
# Date & Time: 2009-01-14 20:25:00, State: nc
# Date & Time: 2010-01-14 12:09:00, State: ky
# Date & Time: 2010-11-04 20:45:00, State: tx
# Date & Time: 2012-11-04 20:45:00, State: ga
# Date & Time: 2012-01-14 21:15:00, State: ct
# Date & Time: 2013-01-14 18:00:00, State: az
# Date & Time: 2014-01-14 22:40:00, State: id
# Date & Time: 1975-11-05 00:00:00, State: az
# Date & Time: 1979-01-15 17:00:00, State: ca
# Date & Time: 1997-01-15 23:00:00, State: wa
# Date & Time: 1999-11-05 21:35:00, State: mo
# Date & Time: 2003-01-15 19:00:00, State: wi
# Date & Time: 2004-11-05 05:15:00, State: pa
# Date & Time: 2004-11-05 06:45:00, State: wi
# Date & Time: 2004-01-15 23:00:00, State: mo
# Date & Time: 2005-11-05 19:55:00, State: ca
# Date & Time: 2005-01-15 22:00:00, State: az
# Date & Time: 2005-11-05 23:45:00, State: ca
# Date & Time: 2007-01-15 07:45:00, State: fl
# Date & Time: 2008-01-15 07:47:00, State: la
# Date & Time: 2009-11-05 18:33:00, State: wi
# Date & Time: 2009-11-05 23:59:00, State: la
# Date & Time: 2010-11-05 19:00:00, State: ca
# Date & Time: 2010-11-05 19:30:00, State: ca
# Date & Time: 2011-11-05 20:00:00, State: ky
# Date & Time: 2011-11-05 21:10:00, State: fl
# Date & Time: 2011-11-05 22:00:00, State: ca
# Date & Time: 2011-01-15 22:40:00, State: vt
# Date & Time: 2012-11-05 01:24:00, State: fl
# Date & Time: 2012-11-05 18:20:00, State: ct
# Date & Time: 2012-11-05 18:30:00, State: or
# Date & Time: 2012-01-15 20:30:00, State: fl
# Date & Time: 2013-11-05 18:45:00, State: az
# Date & Time: 2013-11-05 19:00:00, State: or
# Date & Time: 2013-11-05 20:20:00, State: oh
# Date & Time: 2013-11-05 21:30:00, State: fl
# Date & Time: 2014-01-15 20:10:00, State: ca
# Date & Time: NaT, State: hi
# Date & Time: 1998-11-06 21:15:00, State: az
# Date & Time: 2004-11-06 01:15:00, State: mn
# Date & Time: 2004-11-06 18:00:00, State: pa
# Date & Time: 2005-11-06 19:50:00, State: mo
# Date & Time: 2005-11-06 20:02:00, State: ny
# Date & Time: 2005-11-06 21:53:00, State: ca
# Date & Time: 2011-11-06 01:00:00, State: ma
# Date & Time: 2011-11-06 18:35:00, State: ca
# Date & Time: 2012-01-16 20:15:00, State: ct
# Date & Time: 2013-11-06 17:10:00, State: va
# Date & Time: 2013-11-06 19:50:00, State: ca
# Date & Time: 2014-01-16 19:00:00, State: mo
# Date & Time: 1999-01-17 23:00:00, State: ms
# Date & Time: 2003-11-07 07:00:00, State: wa
# Date & Time: 2005-11-07 17:00:00, State: ia
# Date & Time: 2006-11-07 01:15:00, State: ca
# Date & Time: 2007-11-07 17:30:00, State: ca
# Date & Time: 2008-11-07 18:30:00, State: oh
# Date & Time: 2011-11-07 18:30:00, State: ca
# Date & Time: 2011-01-17 19:55:00, State: nj
# Date & Time: 2012-01-17 13:20:00, State: ca
# Date & Time: 2012-01-17 18:45:00, State: ca
# Date & Time: 2012-11-07 19:45:00, State: oh
# Date & Time: 2012-11-07 21:00:00, State: fl
# Date & Time: 2012-01-17 21:08:00, State: ca
# Date & Time: 2012-11-07 22:10:00, State: ne
# Date & Time: 2012-11-07 23:00:00, State: ne
# Date & Time: 2013-11-07 22:00:00, State: hi
# Date & Time: 2000-01-18 18:15:00, State: ca
# Date & Time: 2000-11-08 22:00:00, State: wv
# Date & Time: 2002-01-18 22:50:00, State: ca
# Date & Time: 2007-11-08 22:00:00, State: md
# Date & Time: 2007-11-08 23:30:00, State: nm
# Date & Time: 2009-11-08 19:10:00, State: ca
# Date & Time: 2011-11-08 18:30:00, State: in
# Date & Time: 2012-11-08 01:30:00, State: co
# Date & Time: 2012-11-08 17:50:00, State: tx
# Date & Time: 2012-11-08 19:45:00, State: mo
# Date & Time: 2012-01-18 19:50:00, State: sc
# Date & Time: 2012-11-08 20:40:00, State: fl
# Date & Time: 2012-01-18 21:04:00, State: ca
# Date & Time: 2014-01-18 20:00:00, State: ca
# Date & Time: 2014-01-18 20:30:00, State: wv
# Date & Time: 2014-01-18 20:30:00, State: me
# Date & Time: 2014-01-18 20:45:00, State: az
# Date & Time: 2014-01-18 21:00:00, State: az
# Date & Time: 2014-01-18 21:30:00, State: az
# Date & Time: 2001-01-19 19:00:00, State: wa
# Date & Time: 2006-01-19 04:00:00, State: nc
# Date & Time: 2008-11-09 22:03:00, State: wa
# Date & Time: 2009-11-09 18:15:00, State: co
# Date & Time: 2009-11-09 21:00:00, State: mt
# Date & Time: 2010-11-09 20:00:00, State: va
# Date & Time: 2010-11-09 21:25:00, State: fl
# Date & Time: 2012-01-19 19:30:00, State: vt
# Date & Time: 2012-01-19 19:35:00, State: va
# Date & Time: 2012-01-19 19:40:00, State: fl
# Date & Time: 2012-01-19 22:10:00, State: fl
# Date & Time: 2012-01-19 23:06:00, State: sc
# Date & Time: 2013-11-09 18:00:00, State: ny
# Date & Time: 2013-11-09 19:15:00, State: in
# Date & Time: 2013-11-09 20:40:00, State: ks
# Date & Time: 2013-01-19 21:00:00, State: ak
# Date & Time: 2013-11-09 21:20:00, State: ks
# Date & Time: 2013-01-19 22:00:00, State: ut
# Date & Time: 2014-01-19 07:00:00, State: az
# Date & Time: 2014-01-19 18:20:00, State: la
# Date & Time: 2000-01-20 21:30:00, State: fl
# Date & Time: 2000-01-20 21:35:00, State: fl
# Date & Time: 2004-01-20 00:00:00, State: ia
# Date & Time: 2010-01-20 20:00:00, State: fl
# Date & Time: 2013-01-20 19:00:00, State: fl
# Date & Time: 2014-01-20 20:00:00, State: tx
# Date & Time: 2014-01-20 20:05:00, State: tx
# Date & Time: 2002-12-10 22:15:00, State: fl
# Date & Time: 2002-12-10 22:55:00, State: fl
# Date & Time: 2007-12-10 19:00:00, State: va
# Date & Time: 2008-12-10 20:40:00, State: pa
# Date & Time: 2010-12-10 15:00:00, State: fl
# Date & Time: 2012-12-10 19:15:00, State: co
# Date & Time: 2012-12-10 20:00:00, State: fl
# Date & Time: 2013-12-10 19:55:00, State: va
# Date & Time: 1996-12-11 19:55:00, State: fl
# Date & Time: 1998-12-11 19:50:00, State: fl
# Date & Time: 1999-12-11 18:00:00, State: nc
# Date & Time: 2000-12-11 21:15:00, State: mo
# Date & Time: 2005-12-11 18:00:00, State: ca
# Date & Time: 2007-12-11 06:00:00, State: ca
# Date & Time: 1975-12-01 02:00:00, State: fl
# Date & Time: 1975-12-01 22:30:00, State: ky
# Date & Time: 1982-12-01 02:00:00, State: ok
# Date & Time: 1997-12-01 23:30:00, State: nj
# Date & Time: 1998-12-01 06:30:00, State: mi
# Date & Time: 1998-12-01 18:00:00, State: in
# Date & Time: 2011-12-26 02:17:00, State: wa
# Date & Time: 2012-12-26 00:30:00, State: wi
# Date & Time: 2012-12-26 18:00:00, State: il
# Date & Time: 2013-12-26 18:00:00, State: co
# Date & Time: 2013-12-26 19:13:00, State: oh
# Date & Time: 2013-12-26 23:30:00, State: ca
# Date & Time: 2003-12-27 16:30:00, State: pa
# Date & Time: 2003-12-27 17:00:00, State: ga
# Date & Time: 2011-12-27 15:50:00, State: mo
# Date & Time: 2012-12-27 17:15:00, State: ny
# Date & Time: 2012-12-27 21:15:00, State: fl
# Date & Time: 2012-12-27 22:20:00, State: fl
# Date & Time: 2013-12-27 19:00:00, State: az
# Date & Time: 2013-12-27 19:30:00, State: ga
# Date & Time: 1999-12-28 05:13:00, State: ut
# Date & Time: 1999-12-28 23:05:00, State: fl
# Date & Time: NaT, State: ky
# Date & Time: 2009-12-28 18:00:00, State: wa
# Date & Time: 2011-12-28 21:00:00, State: tn
# Date & Time: 2011-12-28 21:30:00, State: az
# Date & Time: 2012-12-28 23:00:00, State: fl
# Date & Time: 2012-12-28 23:00:00, State: fl
# Date & Time: 2002-12-29 14:00:00, State: nv
# Date & Time: 2011-12-29 16:30:00, State: tx
# Date & Time: 2012-12-29 00:00:00, State: ca
# Date & Time: 2012-12-29 21:00:00, State: mo
# Date & Time: 2013-12-29 18:15:00, State: fl
# Date & Time: 2013-12-29 18:20:00, State: fl
# Date & Time: 2013-12-29 19:00:00, State: ms
# Date & Time: 2013-12-29 22:50:00, State: fl
# Date & Time: 1959-12-30 18:35:00, State: ca
# Date & Time: 2004-12-30 20:30:00, State: ny
# Date & Time: 2005-12-30 03:00:00, State: ks
# Date & Time: 2009-12-30 06:20:00, State: ct
# Date & Time: 2011-12-30 19:00:00, State: fl
# Date & Time: 2013-12-30 18:30:00, State: ca
# Date & Time: 2013-12-30 19:15:00, State: ca
# Date & Time: 1995-12-31 21:00:00, State: wa
# Date & Time: 1999-12-31 23:59:00, State: ca
# Date & Time: 2006-12-31 16:30:00, State: az
# Date & Time: 2006-12-31 21:47:00, State: ak
# Date & Time: 2008-12-31 21:30:00, State: fl
# Date & Time: 2010-12-31 21:00:00, State: ca
# Date & Time: 2010-12-31 21:47:00, State: tx
# Date & Time: 2010-12-31 23:00:00, State: pa
# Date & Time: 2010-12-31 23:50:00, State: pa
# Date & Time: 2011-12-31 17:05:00, State: wa
# Date & Time: 2011-12-31 18:30:00, State: wa
# Date & Time: 2011-12-31 22:50:00, State: or
# Date & Time: 2011-12-31 23:15:00, State: fl
# Date & Time: 2012-12-31 20:04:00, State: fl
# Date & Time: 2012-12-31 20:28:00, State: az
# Date & Time: 2012-12-31 20:45:00, State: wa
# Date & Time: 2012-12-31 21:00:00, State: az
# Date & Time: 2012-12-31 22:00:00, State: az
# Date & Time: 2012-12-31 22:00:00, State: ct
# Date & Time: 2012-12-31 22:15:00, State: id
# Date & Time: 2012-12-31 22:40:00, State: mt
# Date & Time: 2012-12-31 23:00:00, State: vt
# Date & Time: 2012-12-31 23:00:00, State: ca
# Date & Time: 2012-12-31 23:20:00, State: me
# Date & Time: 2012-12-31 23:30:00, State: fl
# Date & Time: 2012-12-31 23:30:00, State: az
# Date & Time: 2012-12-31 23:45:00, State: sc
# Date & Time: 2012-12-31 23:50:00, State: va
# Date & Time: 2012-12-31 23:54:00, State: ca
# Date & Time: 2012-12-31 23:59:00, State: nv
# Date & Time: 2012-12-31 23:59:00, State: ca
# Date & Time: 2013-12-31 00:29:00, State: vt
# Date & Time: 2013-12-31 19:01:00, State: wa
# Date & Time: 2013-12-31 19:30:00, State: ca
# Date & Time: 2013-12-31 19:54:00, State: wa
# Date & Time: 2013-12-31 20:30:00, State: wa
# Date & Time: 2013-12-31 21:00:00, State: fl
# Date & Time: 2013-12-31 21:00:00, State: or
# Date & Time: 2013-12-31 21:30:00, State: or
# Date & Time: 2013-12-31 21:54:00, State: az
# Date & Time: 2013-12-31 22:00:00, State: tx
# Date & Time: 2013-12-31 22:00:00, State: fl
# Date & Time: 2013-12-31 22:25:00, State: nv
# Date & Time: 2013-12-31 22:30:00, State: sc
# ...
# Date & Time: 1998-09-10 20:00:00, State: tx
# Date & Time: 2006-09-10 23:57:00, State: ca
# Date & Time: 2009-09-10 17:00:00, State: co
# Date & Time: 2011-09-10 09:45:00, State: mi
# Date & Time: 2011-09-10 21:00:00, State: ny
# Date & Time: 2011-09-10 23:30:00, State: id
# Date & Time: 2012-09-10 20:20:00, State: ny
# Date & Time: 2012-09-10 20:30:00, State: nj
# Date & Time: 2012-09-10 20:30:00, State: nj
# Date & Time: 2012-09-10 23:00:00, State: sc
# Date & Time: 2013-09-10 23:00:00, State: wi
# Date & Time: 2004-09-11 20:45:00, State: ny
# Date & Time: 2006-09-11 20:00:00, State: nj
# Date & Time: 2010-09-11 20:00:00, State: nj
# Date & Time: 2011-09-11 00:00:00, State: or
# Date & Time: 2012-09-11 21:32:00, State: mi
# Date & Time: 2012-09-11 23:00:00, State: mi
# Date & Time: 2013-09-11 23:10:00, State: sc
# Date & Time: 1976-09-01 23:00:00, State: ca
# Date & Time: 1996-09-01 22:30:00, State: wi
# Date & Time: 1999-09-01 20:30:00, State: or
# Date & Time: 1999-09-01 21:25:00, State: or
# Date & Time: 1999-09-01 21:30:00, State: ca
# Date & Time: 1999-09-01 21:30:00, State: ca
# Date & Time: 1999-09-01 21:30:00, State: ca
# Date & Time: 1999-09-01 21:30:00, State: nv
# Date & Time: 1999-09-01 21:40:00, State: ca
# Date & Time: 1999-09-01 23:58:00, State: tn
# Date & Time: 2000-09-01 22:00:00, State: az
# Date & Time: 2001-09-01 16:30:00, State: pa
# Date & Time: 2007-09-01 21:05:00, State: mi
# Date & Time: 2007-09-01 21:30:00, State: mi
# Date & Time: 2009-09-01 20:00:00, State: oh
# Date & Time: 2011-09-01 21:00:00, State: me
# Date & Time: 2012-09-01 09:00:00, State: ny
# Date & Time: 2012-09-01 10:28:00, State: ny
# Date & Time: 2012-09-01 20:30:00, State: nj
# Date & Time: 2012-09-01 21:00:00, State: il
# Date & Time: 2012-09-01 21:00:00, State: sc
# Date & Time: 2012-09-01 21:00:00, State: mn
# Date & Time: 2012-09-01 23:15:00, State: wa
# Date & Time: 2013-09-01 02:15:00, State: tx
# Date & Time: 2013-09-01 20:30:00, State: tn
# Date & Time: 2013-09-01 21:00:00, State: oh
# Date & Time: 2013-09-01 21:00:00, State: oh
# Date & Time: 2013-09-01 21:15:00, State: oh
# Date & Time: 2013-09-01 21:15:00, State: ma
# Date & Time: 2013-09-01 22:15:00, State: tn
# Date & Time: 1991-09-12 19:35:00, State: wa
# Date & Time: 1998-09-12 18:00:00, State: fl
# Date & Time: 2001-09-12 12:00:00, State: ca
# Date & Time: 2003-09-12 23:15:00, State: ca
# Date & Time: 2008-09-12 23:00:00, State: ca
# Date & Time: 2009-09-12 02:30:00, State: wi
# Date & Time: 2009-09-12 20:33:00, State: mo
# Date & Time: 2009-09-12 22:00:00, State: mn
# Date & Time: 2009-09-12 22:00:00, State: oh
# Date & Time: 2010-09-12 00:00:00, State: ct
# Date & Time: 2012-09-12 20:22:00, State: tx
# Date & Time: 2012-09-12 20:30:00, State: ny
# Date & Time: 2012-09-12 23:00:00, State: ca
# Date & Time: 2012-09-12 23:13:00, State: ct
# Date & Time: 2013-09-12 00:00:00, State: ca
# Date & Time: 2001-09-13 23:00:00, State: in
# Date & Time: 2001-09-13 23:00:00, State: il
# Date & Time: 2004-09-13 21:05:00, State: ca
# Date & Time: 2007-09-13 20:55:00, State: oh
# Date & Time: 2007-09-13 21:15:00, State: oh
# Date & Time: 2012-09-13 20:00:00, State: sc
# Date & Time: 2013-09-13 19:52:00, State: ky
# Date & Time: 2013-09-13 20:20:00, State: ia
# Date & Time: 2013-09-13 21:00:00, State: ca
# Date & Time: 2013-09-13 21:00:00, State: mi
# Date & Time: 2013-09-13 21:10:00, State: az
# Date & Time: 2003-09-14 16:00:00, State: ca
# Date & Time: 2009-09-14 08:32:00, State: nh
# Date & Time: 2010-09-14 22:00:00, State: mo
# Date & Time: 2010-09-14 23:58:00, State: ga
# Date & Time: 2011-09-14 19:00:00, State: nv
# Date & Time: 2011-09-14 19:40:00, State: nv
# Date & Time: 2011-09-14 20:30:00, State: ca
# Date & Time: 2011-09-14 20:30:00, State: ca
# Date & Time: 2012-09-14 20:00:00, State: ma
# Date & Time: 2012-09-14 21:50:00, State: nc
# Date & Time: 2013-09-14 17:15:00, State: oh
# Date & Time: 2013-09-14 19:02:00, State: ca
# Date & Time: 2013-09-14 20:00:00, State: ny
# Date & Time: 2013-09-14 20:00:00, State: wa
# Date & Time: 2013-09-14 20:53:00, State: la
# Date & Time: 2013-09-14 21:35:00, State: mi
# Date & Time: 2013-09-14 21:45:00, State: ma
# Date & Time: 2013-09-14 22:25:00, State: ga
# Date & Time: 2013-09-14 23:00:00, State: oh
# Date & Time: 2013-09-14 23:10:00, State: nj
# Date & Time: 1957-09-15 21:30:00, State: tx
# Date & Time: NaT, State: sd
# Date & Time: 1998-09-15 20:00:00, State: ca
# Date & Time: 1999-09-15 20:50:00, State: il
# Date & Time: 2007-09-15 19:35:00, State: ri
# Date & Time: 2007-09-15 20:15:00, State: in
# Date & Time: 2008-09-15 19:00:00, State: il
# Date & Time: 2008-09-15 21:00:00, State: va
# Date & Time: 2012-09-15 19:45:00, State: wi
# Date & Time: 2012-09-15 20:30:00, State: fl
# Date & Time: 2012-09-15 21:14:00, State: mi
# Date & Time: 2012-09-15 22:00:00, State: ks
# Date & Time: 2013-09-15 09:30:00, State: fl
# Date & Time: 2013-09-15 20:22:00, State: ct
# Date & Time: 2006-09-16 09:00:00, State: ca
# Date & Time: 2009-09-16 21:00:00, State: mo
# Date & Time: 2011-09-16 21:15:00, State: ca
# Date & Time: 2011-09-16 22:30:00, State: wi
# Date & Time: 2002-09-17 10:00:00, State: oh
# Date & Time: 2005-09-17 22:00:00, State: mt
# Date & Time: 2008-09-17 19:00:00, State: il
# Date & Time: 2008-09-17 23:00:00, State: mi
# Date & Time: 2011-09-17 10:00:00, State: nm
# Date & Time: 2011-09-17 18:30:00, State: oh
# Date & Time: 2012-09-17 21:00:00, State: tx
# Date & Time: 1986-09-18 20:30:00, State: nj
# Date & Time: 1998-09-18 21:30:00, State: ca
# Date & Time: 2005-09-18 20:30:00, State: oh
# Date & Time: 2005-09-18 22:30:00, State: ok
# Date & Time: 2009-09-18 21:00:00, State: pa
# Date & Time: 2010-09-18 20:30:00, State: ny
# Date & Time: 2010-09-18 23:00:00, State: pa
# Date & Time: 2013-09-18 11:00:00, State: al
# Date & Time: 2013-09-18 22:00:00, State: wa
# Date & Time: 2000-09-19 04:20:00, State: ca
# Date & Time: 2002-09-19 19:30:00, State: ca
# Date & Time: 2002-09-19 19:30:00, State: az
# Date & Time: 2002-09-19 19:35:00, State: ca
# Date & Time: 2008-09-19 11:15:00, State: ca
# Date & Time: 2009-09-19 09:00:00, State: il
# Date & Time: 2009-09-19 20:00:00, State: ne
# Date & Time: 2009-09-19 20:00:00, State: ct
# Date & Time: 2009-09-19 20:15:00, State: nj
# Date & Time: 2009-09-19 22:15:00, State: pa
# Date & Time: 2010-09-19 21:00:00, State: ne
# Date & Time: 2012-09-19 22:00:00, State: co
# Date & Time: 2013-09-19 20:00:00, State: ri
# Date & Time: 2013-09-19 20:05:00, State: ny
# Date & Time: 2013-09-19 23:05:00, State: mi
# Date & Time: 1990-09-20 21:30:00, State: wa
# Date & Time: 1994-09-20 06:50:00, State: pa
# Date & Time: 1995-09-20 19:30:00, State: ak
# Date & Time: 2004-09-20 23:00:00, State: ca
# Date & Time: 2005-09-20 07:30:00, State: ky
# Date & Time: 2009-09-20 00:47:00, State: mn
# Date & Time: 2010-09-20 21:02:00, State: ca
# Date & Time: 2010-09-20 21:20:00, State: ca
# Date & Time: 2011-09-20 22:00:00, State: il
# Date & Time: 2013-09-20 04:40:00, State: wa
# Date & Time: 2013-09-20 10:00:00, State: sc
# Date & Time: 2013-09-20 20:00:00, State: ut
# Date & Time: 2013-09-20 20:15:00, State: pa
# Date & Time: 1999-09-21 18:55:00, State: wa
# Date & Time: 1999-09-21 19:15:00, State: id
# Date & Time: 2011-09-21 20:15:00, State: or
# Date & Time: 2011-09-21 21:30:00, State: mn
# Date & Time: 2012-09-21 20:15:00, State: ca
# Date & Time: 2012-09-21 20:47:00, State: mt
# Date & Time: 2012-09-21 21:00:00, State: ct
# Date & Time: 2012-09-21 21:30:00, State: ny
# Date & Time: 2012-09-21 22:45:00, State: ca
# Date & Time: 2013-09-21 19:35:00, State: az
# Date & Time: 2013-09-21 20:30:00, State: oh
# Date & Time: 2013-09-21 21:00:00, State: wi
# Date & Time: 2013-09-21 21:10:00, State: oh
# Date & Time: 2013-09-21 23:00:00, State: oh
# Date & Time: 2013-09-21 23:30:00, State: nj
# Date & Time: 2005-09-02 19:00:00, State: nc
# Date & Time: 2007-09-02 21:15:00, State: in
# Date & Time: 2012-09-02 13:00:00, State: ct
# Date & Time: 2012-09-02 21:00:00, State: sc
# Date & Time: 2012-09-02 21:12:00, State: fl
# Date & Time: 2012-09-02 23:00:00, State: pa
# Date & Time: 2012-09-02 23:30:00, State: ca
# Date & Time: 2013-09-02 20:15:00, State: oh
# Date & Time: 2013-09-02 22:45:00, State: wa
# Date & Time: 1974-09-22 17:00:00, State: ca
# Date & Time: 1998-09-22 04:45:00, State: co
# Date & Time: 2005-09-22 19:20:00, State: ca
# Date & Time: 2005-09-22 19:28:00, State: ca
# Date & Time: 2005-09-22 19:30:00, State: ca
# Date & Time: 2005-09-22 19:30:00, State: az
# Date & Time: 2005-09-22 19:30:00, State: az
# Date & Time: 2007-09-22 21:20:00, State: mi
# Date & Time: 2007-09-22 22:00:00, State: or
# Date & Time: 2010-09-22 21:00:00, State: ca
# Date & Time: 2010-09-22 22:10:00, State: or
# Date & Time: 2011-09-22 22:25:00, State: ca
# Date & Time: 2012-09-22 19:00:00, State: wi
# Date & Time: 2012-09-22 20:00:00, State: il
# Date & Time: 2012-09-22 21:35:00, State: ca
# Date & Time: 2013-09-22 19:25:00, State: me
# Date & Time: 2013-09-22 20:00:00, State: il
# Date & Time: 2013-09-22 20:00:00, State: ga
# Date & Time: 2013-09-22 21:03:00, State: il
# Date & Time: 1997-09-23 20:00:00, State: vt
# Date & Time: 2011-09-23 19:15:00, State: ny
# Date & Time: 2011-09-23 19:50:00, State: or
# Date & Time: 2012-09-23 14:00:00, State: mi
# Date & Time: 2012-09-23 18:55:00, State: pa
# Date & Time: 2012-09-23 18:55:00, State: pa
# Date & Time: 2012-09-23 19:00:00, State: wi
# Date & Time: 2012-09-23 21:30:00, State: ca
# Date & Time: 2013-09-23 19:30:00, State: oh
# Date & Time: 2013-09-23 19:30:00, State: ca
# Date & Time: 2013-09-23 20:00:00, State: oh
# Date & Time: 2013-09-23 20:45:00, State: co
# Date & Time: 1998-09-24 22:30:00, State: ny
# Date & Time: 1999-09-24 18:00:00, State: pa
# Date & Time: 2005-09-30 02:10:00, State: az
# Date & Time: 2005-09-30 18:45:00, State: nv
# Date & Time: 2011-09-30 20:30:00, State: ct
# Date & Time: 2011-09-30 23:00:00, State: wa
# Date & Time: 2011-09-30 23:15:00, State: wa
# Date & Time: 2012-09-30 00:00:00, State: in
# Date & Time: 2012-09-30 00:16:00, State: mn
# Date & Time: 2012-09-30 20:15:00, State: or
# Date & Time: 2012-09-30 21:45:00, State: il
# Date & Time: 1967-09-03 21:00:00, State: co
# Date & Time: 2000-09-03 02:15:00, State: pa
# Date & Time: 2001-09-03 21:30:00, State: ny
# Date & Time: 2002-09-03 21:10:00, State: nv
# Date & Time: 2004-09-03 20:20:00, State: pa
# Date & Time: 2004-09-03 21:20:00, State: pa
# Date & Time: 2011-09-03 21:15:00, State: ar
# Date & Time: 2011-09-03 21:30:00, State: pa
# Date & Time: 2011-09-03 23:00:00, State: oh
# Date & Time: 2012-09-03 19:00:00, State: nj
# Date & Time: 2012-09-03 21:30:00, State: fl
# Date & Time: 2012-09-03 22:00:00, State: ma
# Date & Time: 1999-09-04 22:30:00, State: ia
# Date & Time: 2003-09-04 21:00:00, State: ca
# Date & Time: 2004-09-04 14:00:00, State: nc
# Date & Time: 2009-09-04 23:00:00, State: oh
# Date & Time: 2010-09-04 20:00:00, State: mo
# Date & Time: 2010-09-04 20:00:00, State: il
# Date & Time: 2010-09-04 20:19:00, State: il
# Date & Time: 2011-09-04 18:30:00, State: oh
# Date & Time: 2011-09-04 20:45:00, State: ia
# Date & Time: 2012-09-04 00:00:00, State: oh
# Date & Time: 2013-09-04 20:50:00, State: ct
# Date & Time: 2013-09-04 21:15:00, State: oh
# Date & Time: 2004-09-05 02:00:00, State: tn
# Date & Time: 2004-09-05 22:10:00, State: tx
# Date & Time: 2005-09-05 21:00:00, State: tx
# Date & Time: 2006-09-05 21:00:00, State: az
# Date & Time: 2009-09-05 20:00:00, State: in
# Date & Time: 2009-09-05 20:30:00, State: nj
# Date & Time: 2010-09-05 18:35:00, State: me
# Date & Time: 2010-09-05 21:30:00, State: ky
# Date & Time: 2010-09-05 23:50:00, State: mn
# Date & Time: 2011-09-05 21:45:00, State: mn
# Date & Time: 2013-09-05 21:00:00, State: pa
# Date & Time: 1999-09-06 09:40:00, State: az
# Date & Time: 2000-09-06 19:15:00, State: wa
# Date & Time: 2000-09-06 22:32:00, State: oh
# Date & Time: 2001-09-06 05:30:00, State: ct
# Date & Time: 2009-09-06 21:00:00, State: il
# Date & Time: 2010-09-06 18:30:00, State: ct
# Date & Time: 2012-09-06 21:04:00, State: ny
# Date & Time: 2013-09-06 01:23:00, State: nj
# Date & Time: 2013-09-06 06:37:00, State: id
# Date & Time: 2013-09-06 23:30:00, State: pa
# Date & Time: 1999-09-07 05:00:00, State: fl
# Date & Time: 1999-09-07 05:03:00, State: fl
# Date & Time: 2003-09-07 00:00:00, State: ca
# Date & Time: 2006-09-07 20:45:00, State: az
# Date & Time: 2008-09-07 23:00:00, State: me
# Date & Time: 2009-09-07 01:50:00, State: mi
# Date & Time: 2011-09-07 20:30:00, State: mo
# Date & Time: 2012-09-07 20:30:00, State: ny
# Date & Time: 2012-09-07 22:00:00, State: wi
# Date & Time: 2012-09-07 23:00:00, State: ak
# Date & Time: 2012-09-07 23:10:00, State: tn
# Date & Time: 2013-09-07 02:35:00, State: co
# Date & Time: 2013-09-07 20:22:00, State: wi
# Date & Time: 2013-09-07 21:16:00, State: in
# Date & Time: 2013-09-07 23:00:00, State: wa
# Date & Time: 2005-09-08 20:30:00, State: az
# Date & Time: 2011-09-08 20:50:00, State: pa
# Date & Time: 2011-09-08 23:00:00, State: il
# Date & Time: 2011-09-08 23:15:00, State: il
# Date & Time: 2012-09-08 00:00:00, State: fl
# Date & Time: 2012-09-08 21:15:00, State: in
# Date & Time: 2012-09-08 21:55:00, State: pa
# Date & Time: 2012-09-08 22:00:00, State: mi
# Date & Time: 2012-09-08 22:45:00, State: fl
# Date & Time: 2013-09-08 22:00:00, State: ks
# Date & Time: 2013-09-08 22:30:00, State: in
# Date & Time: 2013-09-08 23:15:00, State: wa
# Date & Time: 2000-09-09 03:30:00, State: nj
# Date & Time: 2000-09-09 21:30:00, State: ms
# Date & Time: 2000-09-09 22:15:00, State: mi
# Date & Time: 2003-09-09 00:31:00, State: fl
# Date & Time: 2005-09-09 20:55:00, State: tx
# Date & Time: 2010-09-09 22:00:00, State: nm
# Date & Time: 2011-09-09 20:00:00, State: ca
# Date & Time: 2012-09-09 19:05:00, State: tn
# Date & Time: 2012-09-09 20:00:00, State: nc
# Date & Time: 2013-09-09 20:20:00, State: al
# Total Fireball Sightings Over 10 Seconds in the US: 3730

# %% [markdown]
# ## Problem 5: Longest Fireball Sighting
#
# - **Task**: Sort the fireball sightings by duration and determine the longest sighting.
# - **Output**:
#   - Sort the list `fball` by duration in descending order.
#   - Print the datetime and duration of the longest sighting.

# %%
import pandas as pd

# Load the CSV file with low_memory=False to avoid the dtype warning
df = pd.read_csv("ufo-sightings.csv", low_memory=False)

# Ensure duration column is treated as numeric, coerce errors to NaN
df["duration (seconds)"] = pd.to_numeric(df["duration (seconds)"], errors="coerce")

# Filter for fireball sightings
fball = df[df["shape"].str.lower() == "fireball"]

# Sort the fireball sightings by duration in descending order
sorted_fireballs = fball.sort_values(by="duration (seconds)", ascending=False)

# Remove any unrealistic duration values (e.g., more than a day in seconds)
sorted_fireballs = sorted_fireballs[sorted_fireballs["duration (seconds)"] < 86400]

# Get the longest fireball sighting
if not sorted_fireballs.empty:
    longest_fireball = sorted_fireballs.iloc[0]
    print(f"Longest Fireball Sighting:\nDate & Time: {longest_fireball['datetime']}, Duration: {longest_fireball['duration (seconds)']} seconds")
else:
    print("No valid fireball sightings found.")
# Out:
# Longest Fireball Sighting:
# Date & Time: 7/1/2001 02:48, Duration: 37800.0 seconds

# %% [markdown]
# ## Problem 6: State with Longest Fireball Sighting
#
# - **Task**: Identify the state that had the longest lasting fireball sighting.
# - **Output**: Print the state.

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("ufo-sightings.csv", low_memory=False)

# Filter the valid fireball sightings
fireball_sightings = df[df['shape'] == 'fireball'].copy()

# Convert 'duration (seconds)' to numeric, coercing errors to NaN and then fill NaNs with 0
fireball_sightings.loc[:, 'duration (seconds)'] = pd.to_numeric(fireball_sightings['duration (seconds)'], errors='coerce').fillna(0)

# Find the longest fireball sighting
longest_fireball = fireball_sightings.loc[fireball_sightings['duration (seconds)'].idxmax()]

print("State with the Longest Fireball Sighting:", longest_fireball['state'])
# Out:
# State with the Longest Fireball Sighting: va

# %% [markdown]
# ## Problem 7: Filter Insignificant Sightings
#
# - **Task**: Assume any sighting of zero seconds is insignificant. Filter these records out.
# - **Output**: Find and print the shortest sighting duration among the significant records.

# %%
import pandas as pd

# Read the data
df = pd.read_csv("/Users/bdawg/PycharmProjects/PythonProject/Unit1_Fundamentals/Fundamental2/ufo-sightings.csv", low_memory=False)

# Ensure "duration (seconds)" is in a numeric format
df["duration (seconds)"] = pd.to_numeric(df["duration (seconds)"], errors="coerce")

# Filter out sightings with zero duration
significant_sightings = df[df["duration (seconds)"] > 0]

# Find the shortest sighting duration among the significant records
shortest_duration = significant_sightings["duration (seconds)"].min()

# Print the shortest sighting duration
print("Shortest sighting duration (in seconds):", shortest_duration)
# Out:
# Shortest sighting duration (in seconds): 0.001

# %% [markdown]
# ## Problem 8: Top Three Sighted Shapes
#
# - **Task**: Determine the top three most frequent UFO shapes sighted.
# - **Output**:
#   - Create a list from the `shape` column.
#   - Count occurrences and sort.
#   - Print the top three shapes and their counts.

# %%
import csv
from collections import Counter

# Load and read the UFO sightings dataset
ufosightings = []
file_path = "ufo-sightings.csv"

try:
    with open(file_path, newline="", encoding="utf-8") as csvfile:
        reader = csv.DictReader(csvfile)
        ufosightings = list(reader)  # Store all sightings in a list
except FileNotFoundError:
    print(f"File not found: {file_path}")
except Exception as e:
    print(f"Error reading file: {e}")

# Filter sightings that occurred in the US
sightings_us = [s for s in ufosightings if s.get("country") == "us"]

# Count occurrences of each shape
shape_counts = Counter(s["shape"] for s in sightings_us if s.get("shape"))

# Get the top three most common shapes
top_three_shapes = shape_counts.most_common(3)

# Print results
for shape, count in top_three_shapes:
    print(f"Shape: {shape}, Sightings: {count}")
# Out:
# Shape: light, Sightings: 13473
# Shape: triangle, Sightings: 6549
# Shape: circle, Sightings: 6118

# %% [markdown]
# ## Problem 9: Top 10 States with the most UFO sightings
#
# - **Task**: Create a line graph of the following
#   - Top 10 of the US states with the most UFO sightings

# %%
# Write your code here
import matplotlib.pyplot as plt
from collections import Counter

# Ensure sightings_us is defined
sightings_us = [s for s in ufosightings if s.get("country") == "us"]

# Count occurrences of each state
state_counts = Counter(s["state"] for s in sightings_us if s.get("state"))

# Get the top 10 states with the most UFO sightings
top_10_states = state_counts.most_common(10)

# Extract state names and their counts
states, counts = zip(*top_10_states)

# Plot the data
plt.figure(figsize=(10, 5))
plt.plot(states, counts, marker="o", linestyle="-", color="b")

# Formatting the graph
plt.xlabel("State")
plt.ylabel("Number of Sightings")
plt.title("Top 10 US States with the Most UFO Sightings")
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Problem 10: Comparing three years (2010, 2011, 2012) top 10 signthings
#
# - **Task**: Create a line graph of the following
#   - Top 10 of the US states with the most UFO sightings

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# Read the data and inspect the datetime and country columns
df = pd.read_csv("/Users/bdawg/PycharmProjects/PythonProject/Unit1_Fundamentals/Fundamental2/ufo-sightings.csv", low_memory=False)

# Ensure "datetime" is in a standard format
df["datetime"] = pd.to_datetime(df["datetime"], errors="coerce")  # Convert to datetime, handling errors

# Filter for US sightings
sightings_us = df[df["country"] == "us"]

# Filter sightings for each year (assuming datetime column is now correctly formatted)
sightings_2010 = sightings_us[sightings_us["datetime"].dt.year == 2010]
sightings_2011 = sightings_us[sightings_us["datetime"].dt.year == 2011]
sightings_2012 = sightings_us[sightings_us["datetime"].dt.year == 2012]

# Function to count sightings by state
def count_states(sightings):
    return Counter(sightings["state"].dropna())

# Count sightings per state for each year
state_counts_2010 = count_states(sightings_2010).most_common(10)
state_counts_2011 = count_states(sightings_2011).most_common(10)
state_counts_2012 = count_states(sightings_2012).most_common(10)

# Extract the top 10 states and their counts for each year
states_2010, counts_2010 = zip(*state_counts_2010)
states_2011, counts_2011 = zip(*state_counts_2011)
states_2012, counts_2012 = zip(*state_counts_2012)

# Ensure the states are aligned for comparison across years (adding 'N/A' where necessary)
states = list(states_2010)  # Take the states from 2010 (assuming all years have similar states)
states_2011 = list(states_2011) + ['N/A'] * (10 - len(states_2011))  # Ensure 10 states
states_2012 = list(states_2012) + ['N/A'] * (10 - len(states_2012))  # Ensure 10 states

# Plot the data
fig, ax = plt.subplots(figsize=(12, 6))

# Plot lines for each year
ax.plot(states, counts_2010, marker='o', label="2010", color='b')
ax.plot(states, counts_2011, marker='o', label="2011", color='g')
ax.plot(states, counts_2012, marker='o', label="2012", color='r')

# Set the positions of the x-ticks (at each state)
ax.set_xticks(range(len(states)))

# Set the x-tick labels with the corresponding states
ax.set_xticklabels(states, rotation=45, ha="right")

# Formatting the graph
ax.set_xlabel("State")
ax.set_ylabel("Number of Sightings")
ax.set_title("Top 10 US States with the Most UFO Sightings (2010-2012)")
ax.legend()
ax.grid(True)

# Show the plot
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %% [markdown]
# ## Filter the unknown ufo out of the data

# %%
# Filter out UFO sightings where the shape is "unknown" or blank
filtered_sightings = [sighting for sighting in ufosightings if sighting.get("shape") and sighting["shape"].lower() != "unknown"]

# Check the first few records of the filtered data
print(f"Filtered {len(ufosightings) - len(filtered_sightings)} unknown sightings out of {len(ufosightings)}.")
print(f"Remaining sightings: {len(filtered_sightings)}")

# Optionally print a few filtered sightings to verify
print(filtered_sightings[:5])
# Out:
# Filtered 7516 unknown sightings out of 80332.
# Remaining sightings: 72816
# [{'datetime': '10/10/1949 20:30', 'city': 'san marcos', 'state': 'tx', 'country': 'us', 'shape': 'cylinder', 'duration (seconds)': '2700', 'duration (hours/min)': '45 minutes', 'comments': 'This event took place in early fall around 1949-50. It occurred after a Boy Scout meeting in the Baptist Church. The Baptist Church sit', 'date posted': '4/27/2004', 'latitude': '29.8830556', 'longitude ': '-97.9411111'}, {'datetime': '10/10/1949 21:00', 'city': 'lackland afb', 'state': 'tx', 'country': '', 'shape': 'light', 'duration (seconds)': '7200', 'duration (hours/min)': '1-2 hrs', 'comments': '1949 Lackland AFB&#44 TX.  Lights racing across the sky &amp; making 90 degree turns on a dime.', 'date posted': '12/16/2005', 'latitude': '29.38421', 'longitude ': '-98.581082'}, {'datetime': '10/10/1955 17:00', 'city': 'chester (uk/england)', 'state': '', 'country': 'gb', 'shape': 'circle', 'duration (seconds)': '20', 'duration (hours/min)': '20 seconds', 'comments': 'Green/Orange circular disc over Chester&#44 England', 'date posted': '1/21/2008', 'latitude': '53.2', 'longitude ': '-2.916667'}, {'datetime': '10/10/1956 21:00', 'city': 'edna', 'state': 'tx', 'country': 'us', 'shape': 'circle', 'duration (seconds)': '20', 'duration (hours/min)': '1/2 hour', 'comments': 'My older brother and twin sister were leaving the only Edna theater at about 9 PM&#44...we had our bikes and I took a different route home', 'date posted': '1/17/2004', 'latitude': '28.9783333', 'longitude ': '-96.6458333'}, {'datetime': '10/10/1960 20:00', 'city': 'kaneohe', 'state': 'hi', 'country': 'us', 'shape': 'light', 'duration (seconds)': '900', 'duration (hours/min)': '15 minutes', 'comments': 'AS a Marine 1st Lt. flying an FJ4B fighter/attack aircraft on a solo night exercise&#44 I was at 50&#44000&#39 in a &quot;clean&quot; aircraft (no ordinan', 'date posted': '1/22/2004', 'latitude': '21.4180556', 'longitude ': '-157.8036111'}]

# %% [markdown]
# ## Task: Identify the trend in UFO sightings over the years (from the earliest year to 2013) and plot the number of sightings per year.

# %%
# Ensure we are modifying a copy safely
sightings_us = sightings_us.copy()

# Extract the year from the datetime column safely
sightings_us.loc[:, "year"] = sightings_us["datetime"].dt.year

# Count sightings per year from the earliest year to 2013
yearly_sightings = sightings_us[sightings_us["year"] <= 2013]["year"].value_counts().sort_index()

# Plotting the trend of sightings over the years
fig, ax = plt.subplots(figsize=(12, 6))

# Plotting the number of sightings per year
ax.plot(yearly_sightings.index, yearly_sightings.values, marker='o', color='b')

# Formatting the graph
ax.set_xlabel("Year")
ax.set_ylabel("Number of Sightings")
ax.set_title("Trend of UFO Sightings Over the Years (Until 2013)")
ax.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Reason for the sudden spike of UFO sightings
# Between 1995 and 2000, there was a noticeable increase in reported UFO sightings, which could be due to a urbanization, media influence, and psychological factors. As cities expanded and populations became more concentrated, more people live in close proximity to each other, making it more likely for multiple individuals to report the same unidentified flying object. Additionally, the rise of mystery-themed TV shows, movies, and documentaries during this period could have raised public fascination with UFOs, increasing the likelihood of people interpreting unusual phenomena as extraterrestrial encounters. Psychological and social factors also played a role, as an increase in media coverage and cultural interest in UFOs may have led to greater awareness and suggestibility, causing individuals to misinterpret ordinary objects or atmospheric conditions as something more extraordinary.
